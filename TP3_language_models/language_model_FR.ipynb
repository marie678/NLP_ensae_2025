# %% [markdown]
# # NLP Lab : Modèles de langue
#
# Dans ce tp, nous allons constuire les briques principales du modèle GPT2 et entrainer un petit modèle sur des poèmes de Victor Hugo.
#
# Les questions sont posées dans ce notebook, puis pour executer l'entrainement, il faudra modifier le ficher `gpt_single_head.py` aussi disponible dans le reposository git.
#
#
# ## Données
#
# Les données d'entrainement sont un recueil de poèmes de Victor Hugo issu du site [gutenberg.org](https://www.gutenberg.org/). Elles sont disponibles dans le répertoire `data`.
#
# Afin de réduire la complexité du modèle, nous allons modéliser le texte au niveau caractère. Les modèles de language modélisent généralement des séquences de sous-mots en utilisant des [tokenizers](https://huggingface.co/docs/transformers/tokenizer_summary) (BPE, SentencePiece, WordPiece)
#
# Questions :
# >* En utilisant [collections.Counter](https://docs.python.org/3/library/collections.html#collections.Counter), afficher le nombre de caractères différents dans le texte et la fréquence de chaque caractère.

# %%
import collections

with open('data/hugo_contemplations.txt', 'r', encoding='utf-8') as f:
    text = f.read()

print(f'Number of characters in the file: {len(text)}')
##  YOUR CODE HERE
counter = collections.Counter(text)
chars = list(counter.keys())
###

print(f'{len(chars)} different characters')
print(counter)
# Out:
# Number of characters in the file: 285222
# 101 different characters
# Counter({' ': 49127, 'e': 30253, 's': 17987, 'u': 14254, 'r': 14223, 't': 14071, 'a': 14048, 'n': 13725, 'i': 12828, 'o': 12653, 'l': 11638, '\n': 8102, 'm': 6495, 'd': 6375, ',': 6077, 'c': 5074, 'p': 4206, "'": 3820, 'v': 3492, 'é': 2943, 'b': 2783, 'f': 2772, 'h': 2221, 'q': 1956, 'g': 1790, '.': 1420, 'x': 1154, 'L': 1147, '!': 1121, 'E': 1074, ';': 1043, '-': 1020, 'j': 890, 'D': 764, 'è': 725, 'à': 706, 'y': 660, 'I': 627, 'ê': 605, 'C': 593, 'S': 545, 'A': 530, 'Q': 503, 'z': 482, 'J': 471, 'O': 450, 'T': 441, 'P': 435, '?': 388, 'V': 383, 'â': 381, 'N': 362, 'M': 344, 'ù': 298, ':': 294, 'R': 240, 'î': 214, 'U': 208, 'ô': 159, 'X': 150, '1': 146, 'H': 116, 'F': 114, '5': 111, '8': 93, 'B': 78, '«': 74, 'É': 70, '»': 69, 'G': 67, '4': 64, 'û': 62, '3': 47, 'ç': 34, 'À': 33, 'ë': 32, 'ï': 31, '2': 30, '·': 26, 'Ê': 24, '6': 23, '7': 23, 'Ô': 19, '9': 19, 'È': 11, 'k': 10, '0': 10, '_': 8, 'Z': 7, 'Æ': 4, '[': 4, ']': 4, 'w': 3, 'K': 3, 'Y': 3, 'Ë': 2, '(': 2, ')': 2, 'Â': 2, 'Î': 1, 'W': 1})

# %% [markdown]
# ### Encodage / décodage
# Afin de transformer le texte en vecteur pour le réseau de neurones, il faut encoder chaque caractère avec un entier. Les fonctions suivantes opérent l'encodage et le décodage des caractères :

# %%
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: transform a string into a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: transform a list of integers into a string


# test that your encoder/decoder is coherent
testString = "\nDemain, dès l'aube"
assert decode(encode (testString)) ==  testString

# %%
decode(encode (testString))
# Out:
# "\nDemain, dès l'aube"

# %% [markdown]
# ### Découpage Train/Validation
#
# L'objectif étant de prédire des poèmes, il ne faut pas mélanger les lignes aléatoirement. Il faut garder l'ordre des lignes dans le texte et uniquement prendre les premiers 90% pour entrainer et les 10% restants pour contrôler l'apprentissage.
#
# Questions :
# > * Découper en `train_data` (90%) et `val_data` (10%) en utilisant du slicing sur data.

# %%
import torch
# Train and validation splits
data = torch.tensor(encode(text), dtype=torch.long)
## YOUR CODE HERE
# first 90% will be train, rest val
split_idx = int(0.9 * len(data))

train_data = data[:split_idx]
val_data = data[split_idx:]

print(len(text))
print(len(train_data) + len(val_data))
# Out:
# 285222
# 285222

# %% [markdown]
# ### Contexte
#
# Le modèle de langue possède comme paramètre la taille maximale du contexte à considérer pour faire la prédiction du prochain caractère. Ce contexte est appelé `block_size`. Les données d'apprentissage sont donc des séquences de caractères consécutifs, issues de l'ensemble d'entraînenement tirées aléatoirement et de longueur `block_size`.
#
# Si le caractère de début de la séquence est `i`, la séquence de contexte est donc :
# ``` x = data[i:i+block_size]```
# et la valeur à prédire à chaque position dans le contexte est le caractère suivant :
# ```y = [data[i+1:i+block_size+1]```.

# %%
block_size = 8

i  = torch.randint(len(data) - block_size, (1,))
print (i)
x = train_data[i:i+block_size]
y = train_data[i+1:i+1+block_size]

for t in range(block_size):
    context = x[:t+1]
    target = y[t]
    print (f'context is >{decode(context.tolist())}< target is >{decode([target.tolist()])}<')
# Out:
# tensor([33752])
# context is > < target is > <
# context is >  < target is > <
# context is >   < target is > <
# context is >    < target is > <
# context is >     < target is > <
# context is >      < target is >T<
# context is >      T< target is >o<
# context is >      To< target is >u<

# %% [markdown]
# ### Définition des batchs
#
# Les batchs d'entrainement sont constitués de plusieurs séquences de caractères tirées aléatoirement dans `train_data`. Pour choisir aléatoirement une séquence à mettre dans le batch, il faut tirer aléatoirement un point de départ dans `train_data` et extraire les `block_size` caractères suivants. Lors du tirage du point de départ, faire attention à laisser suffisamment de caractères après le point de départ pour avoir une séquence de `block_size` caractères.
#
# Questions :
# > * Créer les batchs `x` en tirant `batch_size` séquences de longeur `block_size` à  partir d'un point `i` tiré aléatoirement. Empiler les exemples avec `torch.stack`.
# > * Créer les batchs `y` en ajoutant le caractère suivant la séquence `x`. Empiler les exemples avec `torch.stack`.

# %%
# 4 séquences de longueur 8 à partir d'un point i 
torch.randint(len(data) - block_size, (4,))
# Out:
# tensor([ 71966, 241156,  62447, 155362])

# %%
batch_size = 4
torch.manual_seed(2023)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ## YOUR CODE HERE
    # select batch_size starting points in the data, store them in a list called starting_points
    starting_points = torch.randint(len(data) - block_size, (batch_size,))

    # x is the sequence of integer starting at each straing point and of length block_size
    x = torch.stack([data[idx:idx+block_size] for idx in starting_points])

    # y is the character after each starting position
    y = torch.stack([data[idx+1:idx+block_size+1] for idx in starting_points])
    ### 
    # send data and target to device
    x, y = x.to(device), y.to(device)
    return x, y

# %% [markdown]
# ### Premier modèle : un bigramme
#
# Le premier modèle que nous allons implémenter est un modèle bigramme. Il prédit le caractère suivant uniquement en fonction du caractère courant. Il est possible de stocker ce modèle dans une simple matrice : pour chaque caractère (en ligne), on stocke la distribution de probabilités sur l'ensemble des caractères suivants (en colonne). On peut donc le stocker dans une simple couche [`Embedding`](https://pytorch.org/docs/stable/generated/torch.nn.Embedding.html).
#
# Questions :
# > * Dans le constructeur, définir une couche Embedding de taille `vocab_size` par `vocab_size`.
# > * Dans forward, appliquer la couche d'embedding au batch de idx (`x`).
# > * Dans forward, définir la loss comme la `cross_entropy` entre la prédiction et target (`y`).

# %%
import torch.nn as nn

# use a gpu if we have one
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self, vocab_size):
        super().__init__()
        # we use a simple vocab_size times vocab_size tensor to store the probabilities 
        # of each token given a single token as context in nn.Embedding
        # YOUR CODE HERE
        self.embedding = nn.Embedding(vocab_size, vocab_size)

        ## 
        
    def forward(self, idx, targets=None):

        # idx and targets are both (Batch,Time) tensor of integers
        # YOUR CODE HERE
        logits = self.embedding(idx)

        ## 
   
        # don't compute loss if we don't have targets
        if targets is None:
            loss = None
        else:
            # print(targets)
            # print(targets.shape)
            # change the shape of the logits and target to match what is needed for CrossEntropyLoss
            # https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html
            Batch, Time, Channels = logits.shape
            logits = logits.view(Batch*Time, Channels)
            targets = targets.view(Batch*Time)
            # print(targets)

            # negative log likelihood between prediction and target
            # YOUR CODE HERE
            loss = nn.functional.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # get the predictions
            logits, loss = self(idx)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = nn.functional.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

vocab_size = len(chars)
model = BigramLanguageModel(vocab_size)
# send the model to device
m = model.to(device)

# %% [markdown]
# #### Modèle avant entraînement
# Le modèle n'a pas encore été entrainé, il est juste initialisé, mais on peut calculer la loss sur un batch aléatoire. Les poids étant initialisés avec une distribution normale N(0,1) sur chaque dimension, la loss attendue après l'initialisation devrait être proche de `-ln(1/vocab_size)` (l'entropie est maximale).

# %%
xb, yb = get_batch('train')
print(f'xb shape: {xb.shape}, yb shape: {yb.shape}')
yb
# Out:
# xb shape: torch.Size([4, 8]), yb shape: torch.Size([4, 8])
# tensor([[53, 52, 29, 30, 35, 43, 42,  3],
#         [38, 42, 14, 29, 34, 34, 39, 30],
#         [29, 30, 43, 42, 14, 52, 32, 14],
#         [44, 35, 21,  3,  0, 35, 14, 69]])

# %%
import math
xb, yb = get_batch('train')
logits, loss = m(xb, yb)
print (logits.shape)
print (f'loss attendue {-math.log(1.0/vocab_size)}')
print (f'loss calculée {loss}')
# Out:
# torch.Size([32, 101])
# loss attendue 4.61512051684126
# loss calculée 4.731143951416016

# %% [markdown]
# Pour utiliser le modèle en prédiction, il faut lui fournir un premier caractère pour amorcer la séquence : c'est le prompt. Dans notre cas, on peut initialiser la génération avec le caractère de retour à la ligne pour débuter une nouvelle phrase.
#
# Questions :
# > * Créer un prompt avec un tenseur de taille (1,1) contenant l'entier correspondant au caractère `\n`.
# > * Générer une séquence de caractères de taille 100 à partir de ce prompt avec les fonctions `m.generate` et `decode`.
# > * Comment est la phrase générée ?

# %%
print(encode(['\n']))
## YOUR CODE HERE
prompt = torch.tensor([encode(['\n'])])
decode(m.generate(prompt, 100)[0].tolist())

### la phrase générée est incompréhensible, ce n'est même pas une phrase
# Out:
# [3]
# "\nFà0«z[·9(\n,ï![ÀûQ·jkË)ùKk'-Ip0pû.[w]V0îC!ûe-Nâ-Q8hÂK: Lè?(»»TZUàyÉ,nFÎHàâçPAË8B3d-IïfP:3daèP)·4,CWOp"

# %% [markdown]
# ### Entrainement
#
# Pour l'entrainement, nous utilisons un optimiseur [AdamW](https://pytorch.org/docs/stable/generated/torch.optim.AdamW.html) avec un learning rate de 1e-3. Une itération d'apprentissage consiste en
# - générer un batch
# - appliquer le réseau de neurones (forward) et calculer la loss (`model(xb, yb)`)
# - calculer le gradient (après avoir remis à zero le gradient cumulé) (`loss.backward()`)
# - mettre à jour les paramètres (`optimizer.step()`).

# %%
block_size
# Out:
# 8

# %%
max_iters = 10000
batch_size = 4
eval_interval = 10
learning_rate = 1e-3
eval_iters = 20

@torch.no_grad() # no gradient is computed here
def estimate_loss():
    """ Estimate the loss on eval_iters batch of train and val sets."""
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

# re-create the model
model = BigramLanguageModel(vocab_size)
m = model.to(device)

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = m(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()
# Out:
# step 0: train loss 5.0289, val loss 4.9528
# step 10: train loss 5.0103, val loss 4.8869
# step 20: train loss 4.9587, val loss 4.8420
# step 30: train loss 5.0062, val loss 4.9246
# step 40: train loss 4.9842, val loss 4.9035
# step 50: train loss 4.9176, val loss 4.8553
# step 60: train loss 4.9807, val loss 4.9043
# step 70: train loss 4.9981, val loss 4.8219
# step 80: train loss 4.8895, val loss 4.8113
# step 90: train loss 4.9318, val loss 4.8743
# step 100: train loss 4.9061, val loss 4.7718
# step 110: train loss 4.8767, val loss 4.8262
# step 120: train loss 4.8455, val loss 4.9433
# step 130: train loss 4.9534, val loss 4.7747
# step 140: train loss 4.8575, val loss 4.8372
# step 150: train loss 4.8433, val loss 4.8367
# step 160: train loss 4.8391, val loss 4.7610
# step 170: train loss 4.8981, val loss 4.7188
# step 180: train loss 4.8464, val loss 4.8451
# step 190: train loss 4.8379, val loss 4.7092
# step 200: train loss 4.8400, val loss 4.8304
# step 210: train loss 4.7795, val loss 4.7154
# step 220: train loss 4.8253, val loss 4.8255
# step 230: train loss 4.7523, val loss 4.7599
# step 240: train loss 4.7821, val loss 4.7962
# step 250: train loss 4.8020, val loss 4.7529
# step 260: train loss 4.7451, val loss 4.6929
# step 270: train loss 4.7202, val loss 4.7708
# step 280: train loss 4.7840, val loss 4.7392
# step 290: train loss 4.7987, val loss 4.7211
# step 300: train loss 4.7692, val loss 4.7559
# step 310: train loss 4.7305, val loss 4.7606
# step 320: train loss 4.6790, val loss 4.6662
# step 330: train loss 4.6732, val loss 4.6885
# step 340: train loss 4.7154, val loss 4.6560
# step 350: train loss 4.6741, val loss 4.7172
# step 360: train loss 4.6830, val loss 4.6257
# step 370: train loss 4.7481, val loss 4.6229
# step 380: train loss 4.6747, val loss 4.5872
# step 390: train loss 4.6184, val loss 4.6443
# step 400: train loss 4.6812, val loss 4.5688
# step 410: train loss 4.6355, val loss 4.6376
# step 420: train loss 4.6487, val loss 4.5701
# step 430: train loss 4.5832, val loss 4.5605
# step 440: train loss 4.6132, val loss 4.6131
# step 450: train loss 4.6639, val loss 4.5591
# step 460: train loss 4.6694, val loss 4.5705
# step 470: train loss 4.5977, val loss 4.5001
# step 480: train loss 4.6150, val loss 4.5240
# step 490: train loss 4.5737, val loss 4.5253
# step 500: train loss 4.5558, val loss 4.4815
# step 510: train loss 4.5798, val loss 4.5127
# step 520: train loss 4.5285, val loss 4.5171
# step 530: train loss 4.5639, val loss 4.4377
# step 540: train loss 4.6133, val loss 4.4289
# step 550: train loss 4.5828, val loss 4.5071
# step 560: train loss 4.5857, val loss 4.5352
# step 570: train loss 4.5120, val loss 4.5967
# step 580: train loss 4.5164, val loss 4.4370
# step 590: train loss 4.5592, val loss 4.5019
# step 600: train loss 4.4489, val loss 4.4325
# step 610: train loss 4.4202, val loss 4.4616
# step 620: train loss 4.4617, val loss 4.4824
# step 630: train loss 4.4864, val loss 4.3651
# step 640: train loss 4.4544, val loss 4.4590
# step 650: train loss 4.4525, val loss 4.3865
# step 660: train loss 4.4623, val loss 4.4121
# step 670: train loss 4.4291, val loss 4.3611
# step 680: train loss 4.4549, val loss 4.3636
# step 690: train loss 4.4304, val loss 4.4311
# step 700: train loss 4.4338, val loss 4.4910
# step 710: train loss 4.4675, val loss 4.4131
# step 720: train loss 4.3877, val loss 4.3219
# step 730: train loss 4.4427, val loss 4.3369
# step 740: train loss 4.3543, val loss 4.3340
# step 750: train loss 4.3645, val loss 4.3409
# step 760: train loss 4.3059, val loss 4.3515
# step 770: train loss 4.4029, val loss 4.4019
# step 780: train loss 4.2810, val loss 4.3459
# step 790: train loss 4.2849, val loss 4.3144
# step 800: train loss 4.3916, val loss 4.3322
# step 810: train loss 4.3788, val loss 4.2242
# step 820: train loss 4.4100, val loss 4.3566
# step 830: train loss 4.3330, val loss 4.2757
# step 840: train loss 4.2864, val loss 4.2995
# step 850: train loss 4.3403, val loss 4.3075
# step 860: train loss 4.2871, val loss 4.3114
# step 870: train loss 4.3112, val loss 4.2831
# step 880: train loss 4.2725, val loss 4.2043
# step 890: train loss 4.3627, val loss 4.2630
# step 900: train loss 4.3235, val loss 4.2095
# step 910: train loss 4.3229, val loss 4.1926
# step 920: train loss 4.2927, val loss 4.2352
# step 930: train loss 4.2904, val loss 4.1560
# step 940: train loss 4.2715, val loss 4.2212
# step 950: train loss 4.2420, val loss 4.2153
# step 960: train loss 4.2442, val loss 4.2146
# step 970: train loss 4.2482, val loss 4.1852
# step 980: train loss 4.2360, val loss 4.1638
# step 990: train loss 4.3088, val loss 4.2617
# step 1000: train loss 4.3077, val loss 4.1422
# step 1010: train loss 4.1639, val loss 4.1703
# step 1020: train loss 4.1923, val loss 4.2398
# step 1030: train loss 4.2442, val loss 4.2476
# step 1040: train loss 4.2078, val loss 4.2157
# step 1050: train loss 4.1916, val loss 4.1445
# step 1060: train loss 4.2163, val loss 4.1684
# step 1070: train loss 4.1550, val loss 4.1396
# step 1080: train loss 4.0887, val loss 4.1469
# step 1090: train loss 4.0848, val loss 4.0613
# step 1100: train loss 4.1938, val loss 4.0789
# step 1110: train loss 4.1237, val loss 4.0536
# step 1120: train loss 4.1684, val loss 4.0305
# step 1130: train loss 4.0844, val loss 4.0324
# step 1140: train loss 4.1212, val loss 4.0844
# step 1150: train loss 4.2009, val loss 4.0723
# step 1160: train loss 4.0838, val loss 4.0873
# step 1170: train loss 4.1554, val loss 4.0862
# step 1180: train loss 4.0974, val loss 4.0833
# step 1190: train loss 4.0669, val loss 4.0543
# step 1200: train loss 4.0323, val loss 4.0640
# step 1210: train loss 4.0798, val loss 4.0817
# step 1220: train loss 4.0552, val loss 4.0842
# step 1230: train loss 4.0679, val loss 3.9440
# step 1240: train loss 3.9909, val loss 4.0866
# step 1250: train loss 4.0321, val loss 4.0823
# step 1260: train loss 4.0426, val loss 3.9748
# step 1270: train loss 4.1108, val loss 4.0690
# step 1280: train loss 4.0230, val loss 4.0442
# step 1290: train loss 4.0049, val loss 3.8898
# step 1300: train loss 4.0425, val loss 4.0097
# step 1310: train loss 4.0489, val loss 3.9560
# step 1320: train loss 3.9612, val loss 3.9762
# step 1330: train loss 4.0202, val loss 3.9906
# step 1340: train loss 3.9501, val loss 3.9803
# step 1350: train loss 4.0492, val loss 3.9705
# step 1360: train loss 4.0199, val loss 3.9626
# step 1370: train loss 3.9064, val loss 3.8882
# step 1380: train loss 3.9619, val loss 4.0156
# step 1390: train loss 3.8817, val loss 3.9994
# step 1400: train loss 3.9871, val loss 3.9238
# step 1410: train loss 3.9750, val loss 3.8870
# step 1420: train loss 3.9446, val loss 3.9565
# step 1430: train loss 3.9629, val loss 3.9286
# step 1440: train loss 3.9325, val loss 3.9428
# step 1450: train loss 3.9724, val loss 3.9040
# step 1460: train loss 3.9394, val loss 3.8806
# step 1470: train loss 3.9203, val loss 3.8628
# step 1480: train loss 3.9006, val loss 3.9140
# step 1490: train loss 3.8845, val loss 3.8467
# step 1500: train loss 3.9056, val loss 3.8515
# step 1510: train loss 3.9005, val loss 3.9048
# step 1520: train loss 3.8923, val loss 3.8466
# step 1530: train loss 3.9003, val loss 3.8204
# step 1540: train loss 3.8725, val loss 3.8639
# step 1550: train loss 3.8316, val loss 3.8704
# step 1560: train loss 3.8829, val loss 3.8642
# step 1570: train loss 3.9070, val loss 3.8531
# step 1580: train loss 3.8382, val loss 3.8485
# step 1590: train loss 3.9015, val loss 3.8099
# step 1600: train loss 3.8392, val loss 3.7509
# step 1610: train loss 3.8854, val loss 3.7816
# step 1620: train loss 3.8201, val loss 3.8687
# step 1630: train loss 3.8483, val loss 3.8052
# step 1640: train loss 3.8856, val loss 3.7751
# step 1650: train loss 3.8044, val loss 3.8219
# step 1660: train loss 3.8602, val loss 3.8917
# step 1670: train loss 3.7842, val loss 3.8914
# step 1680: train loss 3.8879, val loss 3.7666
# step 1690: train loss 3.8017, val loss 3.7290
# step 1700: train loss 3.8107, val loss 3.8123
# step 1710: train loss 3.7644, val loss 3.8582
# step 1720: train loss 3.8219, val loss 3.8808
# step 1730: train loss 3.7252, val loss 3.8246
# step 1740: train loss 3.7889, val loss 3.8163
# step 1750: train loss 3.8622, val loss 3.7136
# step 1760: train loss 3.7766, val loss 3.8063
# step 1770: train loss 3.6965, val loss 3.7004
# step 1780: train loss 3.7158, val loss 3.7889
# step 1790: train loss 3.7720, val loss 3.8034
# step 1800: train loss 3.7679, val loss 3.7616
# step 1810: train loss 3.6498, val loss 3.8621
# step 1820: train loss 3.7169, val loss 3.7614
# step 1830: train loss 3.7505, val loss 3.6464
# step 1840: train loss 3.7252, val loss 3.7396
# step 1850: train loss 3.7810, val loss 3.6417
# step 1860: train loss 3.6991, val loss 3.7318
# step 1870: train loss 3.6749, val loss 3.6846
# step 1880: train loss 3.7114, val loss 3.7522
# step 1890: train loss 3.7027, val loss 3.6621
# step 1900: train loss 3.7536, val loss 3.6822
# step 1910: train loss 3.7329, val loss 3.6630
# step 1920: train loss 3.7179, val loss 3.5986
# step 1930: train loss 3.6983, val loss 3.6912
# step 1940: train loss 3.6679, val loss 3.6519
# step 1950: train loss 3.6396, val loss 3.6551
# step 1960: train loss 3.6823, val loss 3.6970
# step 1970: train loss 3.5801, val loss 3.6252
# step 1980: train loss 3.7188, val loss 3.6605
# step 1990: train loss 3.6238, val loss 3.5870
# step 2000: train loss 3.6474, val loss 3.7052
# step 2010: train loss 3.6853, val loss 3.6643
# step 2020: train loss 3.6547, val loss 3.5992
# step 2030: train loss 3.6217, val loss 3.6325
# step 2040: train loss 3.6139, val loss 3.6011
# step 2050: train loss 3.6866, val loss 3.5907
# step 2060: train loss 3.5873, val loss 3.6116
# step 2070: train loss 3.6301, val loss 3.6991
# step 2080: train loss 3.6284, val loss 3.5624
# step 2090: train loss 3.5633, val loss 3.5755
# step 2100: train loss 3.5270, val loss 3.6463
# step 2110: train loss 3.6293, val loss 3.6407
# step 2120: train loss 3.4901, val loss 3.6135
# step 2130: train loss 3.5532, val loss 3.5869
# step 2140: train loss 3.6330, val loss 3.5480
# step 2150: train loss 3.5982, val loss 3.5323
# step 2160: train loss 3.6086, val loss 3.6458
# step 2170: train loss 3.4801, val loss 3.5293
# step 2180: train loss 3.5276, val loss 3.5176
# step 2190: train loss 3.5254, val loss 3.5405
# step 2200: train loss 3.5150, val loss 3.4435
# step 2210: train loss 3.5371, val loss 3.6396
# step 2220: train loss 3.5242, val loss 3.6053
# step 2230: train loss 3.5531, val loss 3.5377
# step 2240: train loss 3.5414, val loss 3.5359
# step 2250: train loss 3.4486, val loss 3.4697
# step 2260: train loss 3.5557, val loss 3.4999
# step 2270: train loss 3.4600, val loss 3.5148
# step 2280: train loss 3.4967, val loss 3.6092
# step 2290: train loss 3.5224, val loss 3.4910
# step 2300: train loss 3.6002, val loss 3.6005
# step 2310: train loss 3.4857, val loss 3.5430
# step 2320: train loss 3.4884, val loss 3.4935
# step 2330: train loss 3.5022, val loss 3.5707
# step 2340: train loss 3.4481, val loss 3.4275
# step 2350: train loss 3.4797, val loss 3.4776
# step 2360: train loss 3.5546, val loss 3.4929
# step 2370: train loss 3.4457, val loss 3.5147
# step 2380: train loss 3.4323, val loss 3.5037
# step 2390: train loss 3.5615, val loss 3.4870
# step 2400: train loss 3.4020, val loss 3.5139
# step 2410: train loss 3.3945, val loss 3.3937
# step 2420: train loss 3.5416, val loss 3.5538
# step 2430: train loss 3.4915, val loss 3.5290
# step 2440: train loss 3.4896, val loss 3.3947
# step 2450: train loss 3.4500, val loss 3.4551
# step 2460: train loss 3.4021, val loss 3.4710
# step 2470: train loss 3.3880, val loss 3.4491
# step 2480: train loss 3.4234, val loss 3.4334
# step 2490: train loss 3.4999, val loss 3.4885
# step 2500: train loss 3.4048, val loss 3.4510
# step 2510: train loss 3.4438, val loss 3.4202
# step 2520: train loss 3.4153, val loss 3.4382
# step 2530: train loss 3.4214, val loss 3.4262
# step 2540: train loss 3.4379, val loss 3.4061
# step 2550: train loss 3.3646, val loss 3.4449
# step 2560: train loss 3.4146, val loss 3.3804
# step 2570: train loss 3.3982, val loss 3.3690
# step 2580: train loss 3.3559, val loss 3.4093
# step 2590: train loss 3.3782, val loss 3.4173
# step 2600: train loss 3.4095, val loss 3.3715
# step 2610: train loss 3.3402, val loss 3.3513
# step 2620: train loss 3.3592, val loss 3.3495
# step 2630: train loss 3.3646, val loss 3.4671
# step 2640: train loss 3.3450, val loss 3.3783
# step 2650: train loss 3.3895, val loss 3.3856
# step 2660: train loss 3.3701, val loss 3.4283
# step 2670: train loss 3.3380, val loss 3.3391
# step 2680: train loss 3.3298, val loss 3.3068
# step 2690: train loss 3.2935, val loss 3.2672
# step 2700: train loss 3.2799, val loss 3.2922
# step 2710: train loss 3.3235, val loss 3.2234
# step 2720: train loss 3.3133, val loss 3.4135
# step 2730: train loss 3.3700, val loss 3.2919
# step 2740: train loss 3.2931, val loss 3.4062
# step 2750: train loss 3.3120, val loss 3.2583
# step 2760: train loss 3.3451, val loss 3.3820
# step 2770: train loss 3.3431, val loss 3.2982
# step 2780: train loss 3.2942, val loss 3.3935
# step 2790: train loss 3.3729, val loss 3.2885
# step 2800: train loss 3.3708, val loss 3.2443
# step 2810: train loss 3.2287, val loss 3.2935
# step 2820: train loss 3.2954, val loss 3.2823
# step 2830: train loss 3.2945, val loss 3.2400
# step 2840: train loss 3.3015, val loss 3.3319
# step 2850: train loss 3.3915, val loss 3.4212
# step 2860: train loss 3.2363, val loss 3.3296
# step 2870: train loss 3.3469, val loss 3.3119
# step 2880: train loss 3.3163, val loss 3.3029
# step 2890: train loss 3.2380, val loss 3.2304
# step 2900: train loss 3.2649, val loss 3.2934
# step 2910: train loss 3.2880, val loss 3.3379
# step 2920: train loss 3.2394, val loss 3.2874
# step 2930: train loss 3.2039, val loss 3.2724
# step 2940: train loss 3.3024, val loss 3.3065
# step 2950: train loss 3.2385, val loss 3.2780
# step 2960: train loss 3.2938, val loss 3.2606
# step 2970: train loss 3.1826, val loss 3.3026
# step 2980: train loss 3.3006, val loss 3.2810
# step 2990: train loss 3.2448, val loss 3.2941
# step 3000: train loss 3.2606, val loss 3.2225
# step 3010: train loss 3.2425, val loss 3.2340
# step 3020: train loss 3.1958, val loss 3.3154
# step 3030: train loss 3.1750, val loss 3.1067
# step 3040: train loss 3.2913, val loss 3.2276
# step 3050: train loss 3.2331, val loss 3.2558
# step 3060: train loss 3.1496, val loss 3.2634
# step 3070: train loss 3.2307, val loss 3.3717
# step 3080: train loss 3.2019, val loss 3.2217
# step 3090: train loss 3.1218, val loss 3.2823
# step 3100: train loss 3.1628, val loss 3.3206
# step 3110: train loss 3.1940, val loss 3.2483
# step 3120: train loss 3.2525, val loss 3.2314
# step 3130: train loss 3.1614, val loss 3.1973
# step 3140: train loss 3.1978, val loss 3.2482
# step 3150: train loss 3.2254, val loss 3.2246
# step 3160: train loss 3.1089, val loss 3.2093
# step 3170: train loss 3.1758, val loss 3.1452
# step 3180: train loss 3.1273, val loss 3.2184
# step 3190: train loss 3.1937, val loss 3.2040
# step 3200: train loss 3.1696, val loss 3.2099
# step 3210: train loss 3.1416, val loss 3.2077
# step 3220: train loss 3.1542, val loss 3.1429
# step 3230: train loss 3.1913, val loss 3.2189
# step 3240: train loss 3.0603, val loss 3.1701
# step 3250: train loss 3.1216, val loss 3.1833
# step 3260: train loss 3.1312, val loss 3.1824
# step 3270: train loss 3.1419, val loss 3.2811
# step 3280: train loss 3.2167, val loss 3.1998
# step 3290: train loss 3.1533, val loss 3.1448
# step 3300: train loss 3.0477, val loss 3.1080
# step 3310: train loss 3.1427, val loss 3.1588
# step 3320: train loss 3.1148, val loss 3.1626
# step 3330: train loss 3.1634, val loss 3.2831
# step 3340: train loss 3.0425, val loss 3.1865
# step 3350: train loss 3.0665, val loss 3.0849
# step 3360: train loss 3.0688, val loss 3.2598
# step 3370: train loss 3.1311, val loss 3.1337
# step 3380: train loss 3.1403, val loss 3.1285
# step 3390: train loss 3.1245, val loss 3.0667
# step 3400: train loss 3.1651, val loss 3.0416
# step 3410: train loss 3.1060, val loss 3.1033
# step 3420: train loss 3.1566, val loss 3.1288
# step 3430: train loss 3.1092, val loss 3.1740
# step 3440: train loss 3.1003, val loss 3.2154
# step 3450: train loss 3.1095, val loss 3.1373
# step 3460: train loss 3.1290, val loss 3.1135
# step 3470: train loss 3.1637, val loss 3.2882
# step 3480: train loss 3.0807, val loss 3.2249
# step 3490: train loss 3.1493, val loss 3.1289
# step 3500: train loss 3.1441, val loss 3.2022
# step 3510: train loss 3.1445, val loss 3.0503
# step 3520: train loss 3.1062, val loss 3.1519
# step 3530: train loss 3.1216, val loss 3.0580
# step 3540: train loss 3.0690, val loss 3.1730
# step 3550: train loss 3.0330, val loss 3.0344
# step 3560: train loss 3.0572, val loss 3.1316
# step 3570: train loss 3.0219, val loss 3.0902
# step 3580: train loss 3.1207, val loss 3.1042
# step 3590: train loss 2.9944, val loss 3.1313
# step 3600: train loss 3.0732, val loss 3.0646
# step 3610: train loss 3.0826, val loss 3.1548
# step 3620: train loss 3.0272, val loss 3.0396
# step 3630: train loss 2.9650, val loss 3.0276
# step 3640: train loss 3.0372, val loss 3.1095
# step 3650: train loss 3.0956, val loss 3.1513
# step 3660: train loss 3.0910, val loss 3.1378
# step 3670: train loss 3.0836, val loss 3.0262
# step 3680: train loss 3.0732, val loss 3.0037
# step 3690: train loss 3.0350, val loss 2.9825
# step 3700: train loss 3.0997, val loss 3.0386
# step 3710: train loss 3.0277, val loss 3.0319
# step 3720: train loss 3.0056, val loss 3.0319
# step 3730: train loss 3.0233, val loss 3.0997
# step 3740: train loss 3.0250, val loss 3.1463
# step 3750: train loss 2.9899, val loss 3.2238
# step 3760: train loss 3.0179, val loss 3.0452
# step 3770: train loss 3.0697, val loss 3.0665
# step 3780: train loss 3.0254, val loss 3.1390
# step 3790: train loss 3.0074, val loss 3.0951
# step 3800: train loss 3.0747, val loss 3.0721
# step 3810: train loss 3.0976, val loss 3.0094
# step 3820: train loss 3.0928, val loss 2.9623
# step 3830: train loss 3.0789, val loss 3.0239
# step 3840: train loss 3.0106, val loss 3.0326
# step 3850: train loss 2.9987, val loss 3.0584
# step 3860: train loss 3.0778, val loss 3.0410
# step 3870: train loss 3.0450, val loss 3.0903
# step 3880: train loss 3.0495, val loss 3.0766
# step 3890: train loss 2.9705, val loss 3.0123
# step 3900: train loss 2.9658, val loss 2.9958
# step 3910: train loss 2.9621, val loss 3.0247
# step 3920: train loss 3.0083, val loss 3.0284
# step 3930: train loss 3.0101, val loss 3.0010
# step 3940: train loss 2.9980, val loss 3.0026
# step 3950: train loss 3.0119, val loss 2.8549
# step 3960: train loss 2.9221, val loss 3.0380
# step 3970: train loss 2.9204, val loss 2.9346
# step 3980: train loss 2.9931, val loss 2.9653
# step 3990: train loss 2.9686, val loss 3.0872
# step 4000: train loss 3.0031, val loss 3.0025
# step 4010: train loss 2.9274, val loss 3.0795
# step 4020: train loss 2.9812, val loss 3.0266
# step 4030: train loss 2.9225, val loss 2.9560
# step 4040: train loss 2.9610, val loss 3.0084
# step 4050: train loss 2.9468, val loss 3.0486
# step 4060: train loss 2.9786, val loss 2.9850
# step 4070: train loss 2.9512, val loss 3.0503
# step 4080: train loss 2.9460, val loss 3.0721
# step 4090: train loss 3.0098, val loss 2.9469
# step 4100: train loss 2.9226, val loss 3.1055
# step 4110: train loss 2.9550, val loss 2.9440
# step 4120: train loss 2.9113, val loss 2.9999
# step 4130: train loss 2.9360, val loss 2.9717
# step 4140: train loss 2.8822, val loss 3.0146
# step 4150: train loss 2.9133, val loss 3.0461
# step 4160: train loss 2.9599, val loss 2.9332
# step 4170: train loss 2.9152, val loss 2.9950
# step 4180: train loss 2.9376, val loss 3.0501
# step 4190: train loss 2.8980, val loss 2.9951
# step 4200: train loss 3.0266, val loss 3.0167
# step 4210: train loss 2.9810, val loss 2.9249
# step 4220: train loss 3.0233, val loss 2.8703
# step 4230: train loss 2.9520, val loss 2.9012
# step 4240: train loss 2.8982, val loss 2.9675
# step 4250: train loss 2.9861, val loss 2.9358
# step 4260: train loss 2.9663, val loss 2.9763
# step 4270: train loss 2.9841, val loss 2.9925
# step 4280: train loss 2.8678, val loss 2.9053
# step 4290: train loss 2.8908, val loss 3.0531
# step 4300: train loss 2.9622, val loss 2.9602
# step 4310: train loss 2.9219, val loss 3.0103
# step 4320: train loss 2.9233, val loss 3.0059
# step 4330: train loss 2.9539, val loss 3.0914
# step 4340: train loss 2.9546, val loss 2.9602
# step 4350: train loss 2.9443, val loss 3.0291
# step 4360: train loss 2.8684, val loss 3.0105
# step 4370: train loss 2.8998, val loss 2.9326
# step 4380: train loss 2.9302, val loss 2.9204
# step 4390: train loss 2.9492, val loss 2.9301
# step 4400: train loss 2.9138, val loss 3.0163
# step 4410: train loss 2.8310, val loss 2.9133
# step 4420: train loss 2.8539, val loss 2.9621
# step 4430: train loss 2.8677, val loss 2.8812
# step 4440: train loss 2.9506, val loss 2.9172
# step 4450: train loss 2.8940, val loss 2.9968
# step 4460: train loss 2.9753, val loss 3.0437
# step 4470: train loss 2.8534, val loss 3.0536
# step 4480: train loss 2.9112, val loss 2.9286
# step 4490: train loss 2.9234, val loss 2.9436
# step 4500: train loss 2.9258, val loss 2.9450
# step 4510: train loss 2.9063, val loss 3.0471
# step 4520: train loss 2.9506, val loss 2.8859
# step 4530: train loss 2.8333, val loss 3.0864
# step 4540: train loss 2.9122, val loss 2.8412
# step 4550: train loss 2.9339, val loss 2.9823
# step 4560: train loss 2.8744, val loss 2.9176
# step 4570: train loss 2.8898, val loss 2.9684
# step 4580: train loss 2.8323, val loss 3.0176
# step 4590: train loss 2.8600, val loss 2.8882
# step 4600: train loss 2.8416, val loss 2.9004
# step 4610: train loss 2.7875, val loss 2.9990
# step 4620: train loss 2.8525, val loss 2.9624
# step 4630: train loss 2.9107, val loss 2.8508
# step 4640: train loss 2.7755, val loss 2.9193
# step 4650: train loss 2.8510, val loss 2.8746
# step 4660: train loss 2.8743, val loss 2.9647
# step 4670: train loss 2.8621, val loss 2.9439
# step 4680: train loss 2.8878, val loss 2.9566
# step 4690: train loss 2.8900, val loss 2.9433
# step 4700: train loss 2.8955, val loss 2.8307
# step 4710: train loss 2.8417, val loss 2.8619
# step 4720: train loss 2.8694, val loss 2.9775
# step 4730: train loss 2.8936, val loss 2.8588
# step 4740: train loss 2.8470, val loss 2.8926
# step 4750: train loss 2.7765, val loss 2.8807
# step 4760: train loss 2.8460, val loss 2.9097
# step 4770: train loss 2.7984, val loss 2.9044
# step 4780: train loss 2.8221, val loss 2.8916
# step 4790: train loss 2.9301, val loss 2.9958
# step 4800: train loss 2.8045, val loss 2.9621
# step 4810: train loss 2.8713, val loss 3.0282
# step 4820: train loss 2.8459, val loss 2.9116
# step 4830: train loss 2.7547, val loss 2.8599
# step 4840: train loss 2.7858, val loss 2.9077
# step 4850: train loss 2.8678, val loss 2.8818
# step 4860: train loss 2.8617, val loss 2.8279
# step 4870: train loss 2.8336, val loss 2.8957
# step 4880: train loss 2.8242, val loss 2.7390
# step 4890: train loss 2.8250, val loss 2.8729
# step 4900: train loss 2.8735, val loss 2.8487
# step 4910: train loss 2.8962, val loss 2.8977
# step 4920: train loss 2.8113, val loss 2.8750
# step 4930: train loss 2.8744, val loss 2.9430
# step 4940: train loss 2.8666, val loss 3.0008
# step 4950: train loss 2.8220, val loss 2.9730
# step 4960: train loss 2.8156, val loss 2.9245
# step 4970: train loss 2.7991, val loss 2.8590
# step 4980: train loss 2.7661, val loss 2.8368
# step 4990: train loss 2.7698, val loss 2.8844
# step 5000: train loss 2.8633, val loss 2.7642
# step 5010: train loss 2.7901, val loss 2.9647
# step 5020: train loss 2.7880, val loss 2.8652
# step 5030: train loss 2.8040, val loss 2.8209
# step 5040: train loss 2.7544, val loss 2.7610
# step 5050: train loss 2.8204, val loss 2.9455
# step 5060: train loss 2.7957, val loss 2.8460
# step 5070: train loss 2.8166, val loss 2.8975
# step 5080: train loss 2.7697, val loss 2.9481
# step 5090: train loss 2.7983, val loss 2.8483
# step 5100: train loss 2.7939, val loss 2.8365
# step 5110: train loss 2.8206, val loss 2.7886
# step 5120: train loss 2.7815, val loss 2.8264
# step 5130: train loss 2.7822, val loss 2.9124
# step 5140: train loss 2.7728, val loss 2.8702
# step 5150: train loss 2.7565, val loss 2.7869
# step 5160: train loss 2.7762, val loss 2.9883
# step 5170: train loss 2.8160, val loss 2.8990
# step 5180: train loss 2.7809, val loss 2.7973
# step 5190: train loss 2.8148, val loss 2.8974
# step 5200: train loss 2.6887, val loss 2.8646
# step 5210: train loss 2.7355, val loss 2.7733
# step 5220: train loss 2.8050, val loss 2.8662
# step 5230: train loss 2.7649, val loss 2.7707
# step 5240: train loss 2.8901, val loss 2.8946
# step 5250: train loss 2.8014, val loss 2.9008
# step 5260: train loss 2.8185, val loss 2.8139
# step 5270: train loss 2.7409, val loss 2.8648
# step 5280: train loss 2.8383, val loss 2.7633
# step 5290: train loss 2.7364, val loss 2.8854
# step 5300: train loss 2.7943, val loss 2.8251
# step 5310: train loss 2.7307, val loss 2.8147
# step 5320: train loss 2.7280, val loss 2.7606
# step 5330: train loss 2.7533, val loss 2.8292
# step 5340: train loss 2.7574, val loss 2.7885
# step 5350: train loss 2.7983, val loss 2.6610
# step 5360: train loss 2.7361, val loss 2.8354
# step 5370: train loss 2.6829, val loss 2.8347
# step 5380: train loss 2.7202, val loss 2.8879
# step 5390: train loss 2.7573, val loss 2.8078
# step 5400: train loss 2.7936, val loss 2.8507
# step 5410: train loss 2.8176, val loss 2.7714
# step 5420: train loss 2.7134, val loss 2.8121
# step 5430: train loss 2.7903, val loss 2.7990
# step 5440: train loss 2.7695, val loss 2.7542
# step 5450: train loss 2.7380, val loss 2.9394
# step 5460: train loss 2.7534, val loss 2.9189
# step 5470: train loss 2.7537, val loss 2.7436
# step 5480: train loss 2.7448, val loss 2.7723
# step 5490: train loss 2.6946, val loss 2.8145
# step 5500: train loss 2.7599, val loss 2.7777
# step 5510: train loss 2.7523, val loss 2.8222
# step 5520: train loss 2.8194, val loss 2.7999
# step 5530: train loss 2.7920, val loss 2.7895
# step 5540: train loss 2.7542, val loss 2.8832
# step 5550: train loss 2.7937, val loss 2.7733
# step 5560: train loss 2.7986, val loss 2.8625
# step 5570: train loss 2.7363, val loss 2.7922
# step 5580: train loss 2.6831, val loss 2.8258
# step 5590: train loss 2.6482, val loss 2.8009
# step 5600: train loss 2.7410, val loss 2.8245
# step 5610: train loss 2.6806, val loss 2.7954
# step 5620: train loss 2.7567, val loss 2.7821
# step 5630: train loss 2.7086, val loss 2.8177
# step 5640: train loss 2.7564, val loss 2.6891
# step 5650: train loss 2.8097, val loss 2.8539
# step 5660: train loss 2.7000, val loss 2.8356
# step 5670: train loss 2.6745, val loss 2.7247
# step 5680: train loss 2.7174, val loss 2.8695
# step 5690: train loss 2.7398, val loss 2.7048
# step 5700: train loss 2.7232, val loss 2.7339
# step 5710: train loss 2.7240, val loss 2.8203
# step 5720: train loss 2.6861, val loss 2.8172
# step 5730: train loss 2.7161, val loss 2.8176
# step 5740: train loss 2.7469, val loss 2.7985
# step 5750: train loss 2.7290, val loss 2.7425
# step 5760: train loss 2.7188, val loss 2.6864
# step 5770: train loss 2.6649, val loss 2.7812
# step 5780: train loss 2.7006, val loss 2.7198
# step 5790: train loss 2.6582, val loss 2.7233
# step 5800: train loss 2.7238, val loss 2.7603
# step 5810: train loss 2.7098, val loss 2.8100
# step 5820: train loss 2.8016, val loss 2.7907
# step 5830: train loss 2.7220, val loss 2.7215
# step 5840: train loss 2.7317, val loss 2.8437
# step 5850: train loss 2.7558, val loss 2.7202
# step 5860: train loss 2.6084, val loss 2.6924
# step 5870: train loss 2.7323, val loss 2.8110
# step 5880: train loss 2.7621, val loss 2.8095
# step 5890: train loss 2.6558, val loss 2.7883
# step 5900: train loss 2.7515, val loss 2.8491
# step 5910: train loss 2.7482, val loss 2.7599
# step 5920: train loss 2.7113, val loss 2.8189
# step 5930: train loss 2.7339, val loss 2.7455
# step 5940: train loss 2.6955, val loss 2.7988
# step 5950: train loss 2.7360, val loss 2.7615
# step 5960: train loss 2.6426, val loss 2.8853
# step 5970: train loss 2.6431, val loss 2.8295
# step 5980: train loss 2.7593, val loss 2.7978
# step 5990: train loss 2.7232, val loss 2.8189
# step 6000: train loss 2.6451, val loss 2.7765
# step 6010: train loss 2.7156, val loss 2.8055
# step 6020: train loss 2.6485, val loss 2.8353
# step 6030: train loss 2.7274, val loss 2.7866
# step 6040: train loss 2.6874, val loss 2.7396
# step 6050: train loss 2.6547, val loss 2.8403
# step 6060: train loss 2.7204, val loss 2.7791
# step 6070: train loss 2.6870, val loss 2.7528
# step 6080: train loss 2.7342, val loss 2.8061
# step 6090: train loss 2.5901, val loss 2.8080
# step 6100: train loss 2.7366, val loss 2.6988
# step 6110: train loss 2.6783, val loss 2.7158
# step 6120: train loss 2.7256, val loss 2.8391
# step 6130: train loss 2.6780, val loss 2.7280
# step 6140: train loss 2.6855, val loss 2.7279
# step 6150: train loss 2.7019, val loss 2.7962
# step 6160: train loss 2.6280, val loss 2.6526
# step 6170: train loss 2.6431, val loss 2.7110
# step 6180: train loss 2.7132, val loss 2.8403
# step 6190: train loss 2.6322, val loss 2.7700
# step 6200: train loss 2.7730, val loss 2.8548
# step 6210: train loss 2.6380, val loss 2.8806
# step 6220: train loss 2.6055, val loss 2.7406
# step 6230: train loss 2.6651, val loss 2.7357
# step 6240: train loss 2.6513, val loss 2.7785
# step 6250: train loss 2.6758, val loss 2.7247
# step 6260: train loss 2.5831, val loss 2.7818
# step 6270: train loss 2.6281, val loss 2.7403
# step 6280: train loss 2.7772, val loss 2.6999
# step 6290: train loss 2.7172, val loss 2.6839
# step 6300: train loss 2.7202, val loss 2.7237
# step 6310: train loss 2.7489, val loss 2.8742
# step 6320: train loss 2.6641, val loss 2.7009
# step 6330: train loss 2.6948, val loss 2.6276
# step 6340: train loss 2.6806, val loss 2.7555
# step 6350: train loss 2.6421, val loss 2.7565
# step 6360: train loss 2.5974, val loss 2.7319
# step 6370: train loss 2.6672, val loss 2.7386
# step 6380: train loss 2.6054, val loss 2.8190
# step 6390: train loss 2.6554, val loss 2.7476
# step 6400: train loss 2.7210, val loss 2.7435
# step 6410: train loss 2.6459, val loss 2.7473
# step 6420: train loss 2.6774, val loss 2.6319
# step 6430: train loss 2.6228, val loss 2.8176
# step 6440: train loss 2.6349, val loss 2.7598
# step 6450: train loss 2.6600, val loss 2.6344
# step 6460: train loss 2.6944, val loss 2.6051
# step 6470: train loss 2.6619, val loss 2.7387
# step 6480: train loss 2.6474, val loss 2.7244
# step 6490: train loss 2.6353, val loss 2.5785
# step 6500: train loss 2.6387, val loss 2.6259
# step 6510: train loss 2.6256, val loss 2.6921
# step 6520: train loss 2.5137, val loss 2.7192
# step 6530: train loss 2.6831, val loss 2.6692
# step 6540: train loss 2.6359, val loss 2.6658
# step 6550: train loss 2.7008, val loss 2.8211
# step 6560: train loss 2.5699, val loss 2.6213
# step 6570: train loss 2.6425, val loss 2.7659
# step 6580: train loss 2.6887, val loss 2.6938
# step 6590: train loss 2.6489, val loss 2.6682
# step 6600: train loss 2.6537, val loss 2.7898
# step 6610: train loss 2.6871, val loss 2.6626
# step 6620: train loss 2.7119, val loss 2.6562
# step 6630: train loss 2.6138, val loss 2.7724
# step 6640: train loss 2.6260, val loss 2.7414
# step 6650: train loss 2.5988, val loss 2.6896
# step 6660: train loss 2.5902, val loss 2.7365
# step 6670: train loss 2.6093, val loss 2.7282
# step 6680: train loss 2.7409, val loss 2.6408
# step 6690: train loss 2.6435, val loss 2.6967
# step 6700: train loss 2.5856, val loss 2.7247
# step 6710: train loss 2.6322, val loss 2.5877
# step 6720: train loss 2.7335, val loss 2.6154
# step 6730: train loss 2.6156, val loss 2.7246
# step 6740: train loss 2.6341, val loss 2.7443
# step 6750: train loss 2.6589, val loss 2.7041
# step 6760: train loss 2.6703, val loss 2.7362
# step 6770: train loss 2.5995, val loss 2.5983
# step 6780: train loss 2.6023, val loss 2.7220
# step 6790: train loss 2.6059, val loss 2.5700
# step 6800: train loss 2.7653, val loss 2.6580
# step 6810: train loss 2.6522, val loss 2.6920
# step 6820: train loss 2.6277, val loss 2.7362
# step 6830: train loss 2.5846, val loss 2.6544
# step 6840: train loss 2.5899, val loss 2.7126
# step 6850: train loss 2.5989, val loss 2.6276
# step 6860: train loss 2.7217, val loss 2.8163
# step 6870: train loss 2.5734, val loss 2.6426
# step 6880: train loss 2.5804, val loss 2.7027
# step 6890: train loss 2.6481, val loss 2.6987
# step 6900: train loss 2.5772, val loss 2.6764
# step 6910: train loss 2.6254, val loss 2.6715
# step 6920: train loss 2.5954, val loss 2.6862
# step 6930: train loss 2.6125, val loss 2.7768
# step 6940: train loss 2.6115, val loss 2.6954
# step 6950: train loss 2.5530, val loss 2.7426
# step 6960: train loss 2.5480, val loss 2.7634
# step 6970: train loss 2.6800, val loss 2.7687
# step 6980: train loss 2.6098, val loss 2.7615
# step 6990: train loss 2.6122, val loss 2.7277
# step 7000: train loss 2.6897, val loss 2.6332
# step 7010: train loss 2.5970, val loss 2.7197
# step 7020: train loss 2.6853, val loss 2.6924
# step 7030: train loss 2.6685, val loss 2.5783
# step 7040: train loss 2.5878, val loss 2.7267
# step 7050: train loss 2.6592, val loss 2.7322
# step 7060: train loss 2.6119, val loss 2.6480
# step 7070: train loss 2.5642, val loss 2.5958
# step 7080: train loss 2.6117, val loss 2.6479
# step 7090: train loss 2.6208, val loss 2.6884
# step 7100: train loss 2.5687, val loss 2.5964
# step 7110: train loss 2.5946, val loss 2.5815
# step 7120: train loss 2.5210, val loss 2.8383
# step 7130: train loss 2.5994, val loss 2.7080
# step 7140: train loss 2.5926, val loss 2.6229
# step 7150: train loss 2.6169, val loss 2.6433
# step 7160: train loss 2.6153, val loss 2.6784
# step 7170: train loss 2.5383, val loss 2.7314
# step 7180: train loss 2.6455, val loss 2.7216
# step 7190: train loss 2.5781, val loss 2.6541
# step 7200: train loss 2.6167, val loss 2.8106
# step 7210: train loss 2.5943, val loss 2.7533
# step 7220: train loss 2.6855, val loss 2.7355
# step 7230: train loss 2.7054, val loss 2.7311
# step 7240: train loss 2.5596, val loss 2.6148
# step 7250: train loss 2.6817, val loss 2.7313
# step 7260: train loss 2.6113, val loss 2.6716
# step 7270: train loss 2.6823, val loss 2.6270
# step 7280: train loss 2.5469, val loss 2.6356
# step 7290: train loss 2.5536, val loss 2.7109
# step 7300: train loss 2.5626, val loss 2.7003
# step 7310: train loss 2.5817, val loss 2.6250
# step 7320: train loss 2.6321, val loss 2.6491
# step 7330: train loss 2.6045, val loss 2.7227
# step 7340: train loss 2.6252, val loss 2.7600
# step 7350: train loss 2.5404, val loss 2.7126
# step 7360: train loss 2.6222, val loss 2.7065
# step 7370: train loss 2.6077, val loss 2.6876
# step 7380: train loss 2.6462, val loss 2.6111
# step 7390: train loss 2.5255, val loss 2.7112
# step 7400: train loss 2.6126, val loss 2.7076
# step 7410: train loss 2.5969, val loss 2.8768
# step 7420: train loss 2.6231, val loss 2.6375
# step 7430: train loss 2.6009, val loss 2.6946
# step 7440: train loss 2.5518, val loss 2.6468
# step 7450: train loss 2.5929, val loss 2.6679
# step 7460: train loss 2.5153, val loss 2.6774
# step 7470: train loss 2.6191, val loss 2.5894
# step 7480: train loss 2.6215, val loss 2.6491
# step 7490: train loss 2.5910, val loss 2.6332
# step 7500: train loss 2.5260, val loss 2.7311
# step 7510: train loss 2.5379, val loss 2.6975
# step 7520: train loss 2.5696, val loss 2.6818
# step 7530: train loss 2.6302, val loss 2.6844
# step 7540: train loss 2.6321, val loss 2.6100
# step 7550: train loss 2.5396, val loss 2.6927
# step 7560: train loss 2.6122, val loss 2.5997
# step 7570: train loss 2.5502, val loss 2.6359
# step 7580: train loss 2.5289, val loss 2.6832
# step 7590: train loss 2.5734, val loss 2.6939
# step 7600: train loss 2.6637, val loss 2.6824
# step 7610: train loss 2.6644, val loss 2.5666
# step 7620: train loss 2.6113, val loss 2.6972
# step 7630: train loss 2.5730, val loss 2.6898
# step 7640: train loss 2.5777, val loss 2.7712
# step 7650: train loss 2.6279, val loss 2.5499
# step 7660: train loss 2.6276, val loss 2.5887
# step 7670: train loss 2.5886, val loss 2.6397
# step 7680: train loss 2.5389, val loss 2.5000
# step 7690: train loss 2.5602, val loss 2.5846
# step 7700: train loss 2.6236, val loss 2.6055
# step 7710: train loss 2.5851, val loss 2.6408
# step 7720: train loss 2.6466, val loss 2.6208
# step 7730: train loss 2.5948, val loss 2.6204
# step 7740: train loss 2.6791, val loss 2.6365
# step 7750: train loss 2.5103, val loss 2.7183
# step 7760: train loss 2.6811, val loss 2.6752
# step 7770: train loss 2.5352, val loss 2.7673
# step 7780: train loss 2.6149, val loss 2.7275
# step 7790: train loss 2.4993, val loss 2.6151
# step 7800: train loss 2.5153, val loss 2.6507
# step 7810: train loss 2.5815, val loss 2.6514
# step 7820: train loss 2.5918, val loss 2.6829
# step 7830: train loss 2.6412, val loss 2.6505
# step 7840: train loss 2.6673, val loss 2.7648
# step 7850: train loss 2.5520, val loss 2.6182
# step 7860: train loss 2.5271, val loss 2.7495
# step 7870: train loss 2.5501, val loss 2.5749
# step 7880: train loss 2.6067, val loss 2.5978
# step 7890: train loss 2.5593, val loss 2.5732
# step 7900: train loss 2.4919, val loss 2.5329
# step 7910: train loss 2.5193, val loss 2.4896
# step 7920: train loss 2.5902, val loss 2.6888
# step 7930: train loss 2.5552, val loss 2.6728
# step 7940: train loss 2.5176, val loss 2.6546
# step 7950: train loss 2.5407, val loss 2.6399
# step 7960: train loss 2.5381, val loss 2.5901
# step 7970: train loss 2.5789, val loss 2.6189
# step 7980: train loss 2.5445, val loss 2.5997
# step 7990: train loss 2.5991, val loss 2.5605
# step 8000: train loss 2.4851, val loss 2.6152
# step 8010: train loss 2.5619, val loss 2.5308
# step 8020: train loss 2.5264, val loss 2.5843
# step 8030: train loss 2.5672, val loss 2.5606
# step 8040: train loss 2.5001, val loss 2.6714
# step 8050: train loss 2.5044, val loss 2.6071
# step 8060: train loss 2.5255, val loss 2.7020
# step 8070: train loss 2.5758, val loss 2.6594
# step 8080: train loss 2.5136, val loss 2.7277
# step 8090: train loss 2.4867, val loss 2.5245
# step 8100: train loss 2.5664, val loss 2.5610
# step 8110: train loss 2.5362, val loss 2.6766
# step 8120: train loss 2.5451, val loss 2.6147
# step 8130: train loss 2.4558, val loss 2.5527
# step 8140: train loss 2.5031, val loss 2.7230
# step 8150: train loss 2.5124, val loss 2.6524
# step 8160: train loss 2.5452, val loss 2.5830
# step 8170: train loss 2.6089, val loss 2.5858
# step 8180: train loss 2.6339, val loss 2.7446
# step 8190: train loss 2.5099, val loss 2.6191
# step 8200: train loss 2.5092, val loss 2.6866
# step 8210: train loss 2.6627, val loss 2.6830
# step 8220: train loss 2.6105, val loss 2.6639
# step 8230: train loss 2.5107, val loss 2.6569
# step 8240: train loss 2.6228, val loss 2.6288
# step 8250: train loss 2.5476, val loss 2.7681
# step 8260: train loss 2.5010, val loss 2.5147
# step 8270: train loss 2.5832, val loss 2.5257
# step 8280: train loss 2.4955, val loss 2.5935
# step 8290: train loss 2.5392, val loss 2.5886
# step 8300: train loss 2.6347, val loss 2.4608
# step 8310: train loss 2.5964, val loss 2.6793
# step 8320: train loss 2.5633, val loss 2.5890
# step 8330: train loss 2.4502, val loss 2.5897
# step 8340: train loss 2.5208, val loss 2.5330
# step 8350: train loss 2.5769, val loss 2.5903
# step 8360: train loss 2.5107, val loss 2.5933
# step 8370: train loss 2.5475, val loss 2.5803
# step 8380: train loss 2.6168, val loss 2.6530
# step 8390: train loss 2.5154, val loss 2.5575
# step 8400: train loss 2.5246, val loss 2.5193
# step 8410: train loss 2.5651, val loss 2.5658
# step 8420: train loss 2.4696, val loss 2.6921
# step 8430: train loss 2.5543, val loss 2.6181
# step 8440: train loss 2.5542, val loss 2.5237
# step 8450: train loss 2.5403, val loss 2.6316
# step 8460: train loss 2.5086, val loss 2.6983
# step 8470: train loss 2.6387, val loss 2.5440
# step 8480: train loss 2.5426, val loss 2.6329
# step 8490: train loss 2.5654, val loss 2.5417
# step 8500: train loss 2.5221, val loss 2.6277
# step 8510: train loss 2.5125, val loss 2.6165
# step 8520: train loss 2.5498, val loss 2.5846
# step 8530: train loss 2.5305, val loss 2.5030
# step 8540: train loss 2.5840, val loss 2.6027
# step 8550: train loss 2.5532, val loss 2.7183
# step 8560: train loss 2.6694, val loss 2.7017
# step 8570: train loss 2.5196, val loss 2.7480
# step 8580: train loss 2.5012, val loss 2.6121
# step 8590: train loss 2.4901, val loss 2.5879
# step 8600: train loss 2.5067, val loss 2.5348
# step 8610: train loss 2.5229, val loss 2.6762
# step 8620: train loss 2.5448, val loss 2.6570
# step 8630: train loss 2.6226, val loss 2.7112
# step 8640: train loss 2.5182, val loss 2.5200
# step 8650: train loss 2.5405, val loss 2.6562
# step 8660: train loss 2.5800, val loss 2.5895
# step 8670: train loss 2.5198, val loss 2.6216
# step 8680: train loss 2.6186, val loss 2.5940
# step 8690: train loss 2.5064, val loss 2.5290
# step 8700: train loss 2.5620, val loss 2.5875
# step 8710: train loss 2.5383, val loss 2.6744
# step 8720: train loss 2.5692, val loss 2.7028
# step 8730: train loss 2.4530, val loss 2.6202
# step 8740: train loss 2.5798, val loss 2.6338
# step 8750: train loss 2.4536, val loss 2.5471
# step 8760: train loss 2.4755, val loss 2.6220
# step 8770: train loss 2.5430, val loss 2.5948
# step 8780: train loss 2.5882, val loss 2.6131
# step 8790: train loss 2.4860, val loss 2.6328
# step 8800: train loss 2.4846, val loss 2.6090
# step 8810: train loss 2.4644, val loss 2.5912
# step 8820: train loss 2.5655, val loss 2.6179
# step 8830: train loss 2.5970, val loss 2.5371
# step 8840: train loss 2.5809, val loss 2.4838
# step 8850: train loss 2.5465, val loss 2.5942
# step 8860: train loss 2.5207, val loss 2.5133
# step 8870: train loss 2.6141, val loss 2.5944
# step 8880: train loss 2.5321, val loss 2.6996
# step 8890: train loss 2.4886, val loss 2.5672
# step 8900: train loss 2.4712, val loss 2.6336
# step 8910: train loss 2.4947, val loss 2.5792
# step 8920: train loss 2.5133, val loss 2.5571
# step 8930: train loss 2.4783, val loss 2.6670
# step 8940: train loss 2.5024, val loss 2.5887
# step 8950: train loss 2.4625, val loss 2.5944
# step 8960: train loss 2.5274, val loss 2.6022
# step 8970: train loss 2.5273, val loss 2.5437
# step 8980: train loss 2.6041, val loss 2.5744
# step 8990: train loss 2.4764, val loss 2.5551
# step 9000: train loss 2.4829, val loss 2.5961
# step 9010: train loss 2.4492, val loss 2.6205
# step 9020: train loss 2.5313, val loss 2.6074
# step 9030: train loss 2.5219, val loss 2.5323
# step 9040: train loss 2.5475, val loss 2.4754
# step 9050: train loss 2.5352, val loss 2.5549
# step 9060: train loss 2.5160, val loss 2.5558
# step 9070: train loss 2.5523, val loss 2.5344
# step 9080: train loss 2.6164, val loss 2.5805
# step 9090: train loss 2.6063, val loss 2.6838
# step 9100: train loss 2.5446, val loss 2.5285
# step 9110: train loss 2.5757, val loss 2.5837
# step 9120: train loss 2.5452, val loss 2.5715
# step 9130: train loss 2.4991, val loss 2.6016
# step 9140: train loss 2.6091, val loss 2.5579
# step 9150: train loss 2.4771, val loss 2.5413
# step 9160: train loss 2.5890, val loss 2.6551
# step 9170: train loss 2.4502, val loss 2.5438
# step 9180: train loss 2.4946, val loss 2.6231
# step 9190: train loss 2.4847, val loss 2.5214
# step 9200: train loss 2.5700, val loss 2.6330
# step 9210: train loss 2.5586, val loss 2.6758
# step 9220: train loss 2.4993, val loss 2.6468
# step 9230: train loss 2.4898, val loss 2.6145
# step 9240: train loss 2.5351, val loss 2.5736
# step 9250: train loss 2.5217, val loss 2.6014
# step 9260: train loss 2.5280, val loss 2.6556
# step 9270: train loss 2.4970, val loss 2.6221
# step 9280: train loss 2.4992, val loss 2.4906
# step 9290: train loss 2.4549, val loss 2.6122
# step 9300: train loss 2.5080, val loss 2.6227
# step 9310: train loss 2.4775, val loss 2.5726
# step 9320: train loss 2.4004, val loss 2.5576
# step 9330: train loss 2.5242, val loss 2.5485
# step 9340: train loss 2.4818, val loss 2.6451
# step 9350: train loss 2.5682, val loss 2.7041
# step 9360: train loss 2.5529, val loss 2.6056
# step 9370: train loss 2.4978, val loss 2.6056
# step 9380: train loss 2.4526, val loss 2.5764
# step 9390: train loss 2.5142, val loss 2.6293
# step 9400: train loss 2.4364, val loss 2.6068
# step 9410: train loss 2.5225, val loss 2.5805
# step 9420: train loss 2.5492, val loss 2.6824
# step 9430: train loss 2.5436, val loss 2.5401
# step 9440: train loss 2.4573, val loss 2.5580
# step 9450: train loss 2.4795, val loss 2.6605
# step 9460: train loss 2.4428, val loss 2.5011
# step 9470: train loss 2.4719, val loss 2.6788
# step 9480: train loss 2.4152, val loss 2.6746
# step 9490: train loss 2.5156, val loss 2.6586
# step 9500: train loss 2.4601, val loss 2.4846
# step 9510: train loss 2.4977, val loss 2.6511
# step 9520: train loss 2.4985, val loss 2.4520
# step 9530: train loss 2.5144, val loss 2.6577
# step 9540: train loss 2.5200, val loss 2.5338
# step 9550: train loss 2.5914, val loss 2.5094
# step 9560: train loss 2.4085, val loss 2.5926
# step 9570: train loss 2.5287, val loss 2.5378
# step 9580: train loss 2.4802, val loss 2.8045
# step 9590: train loss 2.5471, val loss 2.7367
# step 9600: train loss 2.4691, val loss 2.5178
# step 9610: train loss 2.5043, val loss 2.6352
# step 9620: train loss 2.5041, val loss 2.5573
# step 9630: train loss 2.4701, val loss 2.6322
# step 9640: train loss 2.5080, val loss 2.7207
# step 9650: train loss 2.5100, val loss 2.4590
# step 9660: train loss 2.5043, val loss 2.6575
# step 9670: train loss 2.4754, val loss 2.5432
# step 9680: train loss 2.4127, val loss 2.4615
# step 9690: train loss 2.5826, val loss 2.5918
# step 9700: train loss 2.5343, val loss 2.6119
# step 9710: train loss 2.5217, val loss 2.6792
# step 9720: train loss 2.5503, val loss 2.5474
# step 9730: train loss 2.4443, val loss 2.6361
# step 9740: train loss 2.5063, val loss 2.5966
# step 9750: train loss 2.3997, val loss 2.5088
# step 9760: train loss 2.4804, val loss 2.6073
# step 9770: train loss 2.5136, val loss 2.6448
# step 9780: train loss 2.4610, val loss 2.6085
# step 9790: train loss 2.4329, val loss 2.6039
# step 9800: train loss 2.4415, val loss 2.5704
# step 9810: train loss 2.4043, val loss 2.6326
# step 9820: train loss 2.5287, val loss 2.5888
# step 9830: train loss 2.4423, val loss 2.6328
# step 9840: train loss 2.4637, val loss 2.4825
# step 9850: train loss 2.4937, val loss 2.5909
# step 9860: train loss 2.4417, val loss 2.5555
# step 9870: train loss 2.4498, val loss 2.5551
# step 9880: train loss 2.4978, val loss 2.6408
# step 9890: train loss 2.4145, val loss 2.6427
# step 9900: train loss 2.5004, val loss 2.5297
# step 9910: train loss 2.5455, val loss 2.5938
# step 9920: train loss 2.5631, val loss 2.5646
# step 9930: train loss 2.4716, val loss 2.5965
# step 9940: train loss 2.5080, val loss 2.5952
# step 9950: train loss 2.5091, val loss 2.5314
# step 9960: train loss 2.5322, val loss 2.7201
# step 9970: train loss 2.4971, val loss 2.5696
# step 9980: train loss 2.5264, val loss 2.5575
# step 9990: train loss 2.4534, val loss 2.5502

# %% [markdown]
# Une fois le réseau entrainé pendant 100 itérations, on peut générer une séquence de caractères.
#
# Questions :
# > * Quel est l'effet de l'entraînement ?
# > * Augmenter le nombre d'itérations à 1000 puis à 10,000, noter la loss obtenue et la phrase générée. Qu'observez-vous ?

# %%
idx = torch.ones((1,1), dtype=torch.long)*3
print (decode(m.generate(idx, max_new_tokens=100)[0].tolist()))
# Out:
# Ragr A qute,
# LÀy[
# gomers Le le.
#
# Qur tus de Le  luit  t yare.
# N le «LKÆ-O ciomples cr8x:mbr éor urem

# %%
# 100 iter : l'entraînement n'a pas changé grand chose : la phrase est toujours incompréhensible et ne ressemble pas à une phrase
# 1000 iter : on note desretours à la ligne mais toujours aucun mot qui fasse sens.
        # 4.4308, val loss 4.4419
# 10 000 iter : on voit l'appartition d'espaces ce qui donne l'illusion d'une phrase visuellement, mais les mots n'ont toujours
# aucun sens, bien qu'ils soient un peu plus proches de mots réels quand même
        # step 9990: train loss 2.5844, val loss 2.5995


# la loss diminue à peine en augmentant le nombre d'itérations de 100 à 1000 mais est divisée par 2 en augmentant jusqu'à 10000 iter

# %% [markdown]
# ## Single Head Attention
#
# Nous allons maintenant implémenter le mécanisme de base de l'attention. Pour chaque couple de mots de la séquence, ce mécanisme combine Q une *query* (l'information recherchée), K une *key* (l'information obtenue) et calcule  V une *value*, un vecteur de résultat.
#
# ![single head attention](images/single_head_attention.png)
#
# ### Masquage
# Cependant, comme nous utilisons le modèle pour générer des séquences, on ne doit pas utiliser les caractères situés après le caractère courant, car ce sont justement ces caractères que l'on cherche à prédire lors de l'apprentissage : *le futur n'est pas utilisé pour prédire (le futur).*
#
# On va donc intégrer une matrice de masquage dans le processus. Cette matrice indique que pour le premier caractère de la séquence, on ne peut utiliser que ce caractère pour prédire (pas de contexte). Pour le second caractère, on peut utiliser le premier caractère et le second. Pour le troisième caractère, on peut utiliser le premier, le second et le troisième et ainsi de suite. Cette matrice est donc une matrice triangulaire inférieure. Cette matrice est normalisée par ligne (les lignes somment à 1).

# %%
T = 8

# first version of the contraints with matrix multiplication
# create a lower triangular matrix
weights0 = torch.tril(torch.ones(T,T))
# normalize each row
weights0 = weights0 / weights0.sum(1, keepdim=True) 
print (weights0)
# Out:
# tensor([[1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.5000, 0.5000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.3333, 0.3333, 0.3333, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2500, 0.2500, 0.2500, 0.2500, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.0000, 0.0000, 0.0000],
#         [0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.0000, 0.0000],
#         [0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.0000],
#         [0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250]])

# %% [markdown]
# La couche [`softmax`](https://pytorch.org/docs/stable/generated/torch.nn.functional.softmax.html) est une autre manière de réaliser la normalisation :
#
# Question :
# > * Vérifier qu'on obtient bien la même matrice. --> c'est bon

# %%
tril = torch.tril(torch.ones(T,T))
weights = torch.tril(torch.ones(T,T))
weights = weights.masked_fill(tril== 0, float('-inf'))
weights = nn.functional.softmax(weights, dim=-1)
print (weights)
# Out:
# tensor([[1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.5000, 0.5000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.3333, 0.3333, 0.3333, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2500, 0.2500, 0.2500, 0.2500, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.0000, 0.0000, 0.0000],
#         [0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.0000, 0.0000],
#         [0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.0000],
#         [0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250]])

# %% [markdown]
# ### Implémentation
#
# Nous pouvons maintenant implémenter la couche d'attention :
#
# ![attention_formula](images/attention_formula.png)

# %% [markdown]
# Questions :
#
# > * Créer les couches key, query et value comme des couches linéaires de dimension `C` x `head_size`.
# > * Appliquer les couches à `x`.
# > * `weights = query x key` (transposer les deuxième et troisième dimensions de key pour pouvoir faire le produit).
# > * Appliquer le facteur de normalisation.
# > * Appliquer le masque triangulaire et la softmax à `weights`.
# > * Appliquer value à `x`.
# > * Le résultat `out` est la multiplication de `weights` par `value(x)`.

# %%
head_size = 16
B, T, C = 4, 8, 32
x = torch.randn(B, T, C)
## YOUR CODE HERE
# define the Key layer  
key = nn.Linear(C, head_size)
# define the Query layer
query = nn.Linear(C, head_size)
# define the Value layer
value =  nn.Linear(C, head_size)
# apply each layer to the input
k =  key(x)# (B, T, head_size)
q =  query(x)# (B, T, head_size)
v =  value(x)# (B, T, head_size)
# compute the normalize product between Q and K 
weights =  q @ k.transpose(1, 2) # (B, T, head_size) @ (B, 16, head_size) -> (B, T, T)
# apply the mask (lower triangular matrix)
weights = weights.masked_fill(tril== 0, float('-inf'))
# apply the softmax
weights = torch.softmax(weights, dim=-1)
###
out  = weights @ value(x) # (B, T, head_size)

# print the result
print(weights[0])
print(out[0])
# Out:
# tensor([[1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00],
#         [3.9243e-01, 6.0757e-01, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00],
#         [6.3102e-01, 3.5530e-01, 1.3676e-02, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00],
#         [6.2706e-01, 1.0794e-01, 3.5490e-02, 2.2950e-01, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00],
#         [9.9507e-02, 1.0658e-01, 7.8735e-02, 1.5356e-01, 5.6162e-01, 0.0000e+00,
#          0.0000e+00, 0.0000e+00],
#         [1.0164e-02, 2.3335e-03, 7.5349e-01, 5.2529e-02, 8.7469e-02, 9.4016e-02,
#          0.0000e+00, 0.0000e+00],
#         [5.5027e-02, 6.2755e-01, 3.0474e-02, 2.4194e-02, 8.4305e-02, 7.8806e-02,
#          9.9641e-02, 0.0000e+00],
#         [1.4109e-01, 4.1034e-03, 1.6502e-02, 8.8691e-03, 3.6057e-01, 4.6419e-01,
#          3.7371e-03, 9.3535e-04]], grad_fn=<SelectBackward0>)
# tensor([[ 9.8975e-01, -4.6750e-01,  4.3580e-02,  7.6286e-02,  1.1700e+00,
#          -5.7486e-01, -2.2065e-01,  4.2254e-01, -4.8595e-01, -5.4960e-01,
#          -5.6517e-01,  1.6300e-01, -8.8277e-01, -5.5722e-01, -6.9383e-01,
#          -1.4003e+00],
#         [ 2.9750e-01, -4.4130e-01, -1.3805e-01,  1.1684e-01,  5.5434e-01,
#          -4.3065e-02,  8.2004e-02,  6.3349e-01,  1.2716e-02, -1.2487e-01,
#           2.8729e-02,  1.5052e-01, -6.0467e-01, -6.2080e-01, -5.2326e-01,
#          -5.3991e-01],
#         [ 5.6840e-01, -4.5185e-01, -6.5167e-02,  1.0163e-01,  7.9119e-01,
#          -2.5879e-01, -3.3619e-02,  5.4446e-01, -1.8951e-01, -2.9164e-01,
#          -2.0622e-01,  1.5412e-01, -7.1878e-01, -5.7674e-01, -5.8570e-01,
#          -8.8113e-01],
#         [ 8.9441e-01, -4.1193e-01, -6.7554e-02,  3.0160e-01,  8.7737e-01,
#          -3.1841e-01, -3.5199e-01,  3.0137e-01, -2.0818e-01, -3.5859e-01,
#          -2.7313e-02,  3.6691e-01, -6.4595e-01, -5.4790e-01, -3.8460e-01,
#          -9.7500e-01],
#         [ 4.2556e-01,  1.0132e-01,  1.4960e-01,  6.6907e-01,  5.4836e-02,
#           6.2717e-02, -3.2227e-01, -5.1703e-02,  1.1839e-01, -3.4747e-01,
#          -2.2128e-01,  3.7217e-01, -6.1597e-01,  1.1049e-02, -7.0300e-04,
#          -7.9390e-01],
#         [-9.0757e-03, -3.1490e-01, -3.6172e-02,  2.2999e-01, -1.8083e-01,
#          -6.2616e-02,  3.6755e-01,  2.5048e-01, -4.5236e-02,  3.6995e-02,
#           1.3430e-01,  5.2905e-02, -6.4470e-01,  5.4128e-01, -1.4585e-02,
#          -2.8697e-01],
#         [ 9.5674e-02, -1.6216e-01, -1.1409e-01,  1.6688e-01,  1.8785e-01,
#           2.4115e-01,  1.9572e-01,  5.6704e-01,  2.2406e-01,  3.7127e-02,
#           9.8605e-02,  9.6026e-02, -4.7830e-01, -4.4874e-01, -3.0643e-01,
#          -1.9205e-01],
#         [ 5.1211e-01,  7.9889e-02,  3.9052e-01,  1.0405e-01, -1.5682e-01,
#           3.5945e-01,  2.0221e-01,  1.8013e-01,  1.3972e-01, -3.4931e-01,
#          -6.9714e-01, -1.9221e-01, -2.9003e-01,  4.8893e-02,  5.3745e-02,
#          -5.2349e-01]], grad_fn=<SelectBackward0>)

# %% [markdown]
# Questions :
#
# > * Copier votre code dans `gpt_single_head.py` : la définition des couches dans le constructeur de la classe `Head` et les calculs dans la fonction `forward`.
# > * Faire un entrainement.
# > * Quelle loss en train et val obtenez vous ? Le texte vous parait-il meilleur ?

# %%
# j'otbiens les loss suivantes : step 4999: train loss 2.3423, val loss 2.4739
# le texte parait meilleur dans le sens ou les "mots" formés se rapprochent de plus en plus de vrais mots,
# on en reconnaît même quelques uns, mais le texte n'a toujours aucun sens.

# %% [markdown]
# ## Multi-head attention
#
# La *multi-head attention* est simplement le calcul en parallèle de plusieurs *single head attention*. Chacune des single head attention est concaténée pour créer la sortie de la multi-head attention. Dans la figure issue de l'article original, le nombre de *heads* dans le *multi-head* est `h`. Afin d'opérer des combinaisons pondérées sur la sortie de chacune des single head, une couche de calcul linéaire est ajoutée.
#
# ![multi head attention](images/multi_head_attention.png)
#
# Le code ci-dessous crée un module de multi-head attention.
# Questions :
# > * Dans le constructeur, créer une liste contenant `num_heads` module `Head` en utilisant la fonction [ModuleList](https://pytorch.org/docs/stable/generated/torch.nn.ModuleList.html) de pytorch.
# > * Dans la fonction `forward`, appliquer chaque single head à l'input et concaténer le résultat en utilisant la fonction [cat](https://pytorch.org/docs/stable/generated/torch.cat.html) de pytorch.

# %%
class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        ## YOUR CODE HERE
        ## list of num_heads modules of type Head
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        ###

    def forward(self, x):
        ## YOUR CODE HERE
        ## apply each head in self.heads to x and concat the results 
        out = torch.cat([h(x) for h in self.heads], dim=-1)

        return out

# %% [markdown]
# Questions :
# > * Copier le fichier `gpt_single_head.py` en `gpt_multi_head.py`.
# > * Ajouter le module MultiHeadAttention dans `gpt_multi_head.py`.
# > * En tête de fichier, ajouter un paramètre  `n_head = 4`.
# > * Dans le module BigramLanguageModel, remplacer le module Head par un module MultiHeadAttention avec les paramètres `num_heads = n_head` et `head_size = n_embd // n_head` pour garder le même nombre de paramètres.
# > Relancer l'entrainement et noter le nombre de paramètres et les loss obtenues.
#
# 0.009893 M parameters
# step 4999: train loss 2.1570, val loss 2.1802

# %%
# 0.009989 M parameters
# step 4999: train loss 2.1476, val loss 2.1939

# %% [markdown]
# ## Ajout d'une couche de calcul FeedForward
#
#
# Après les couches d'attention qui collectent l'information dans la séquence, une couche de calcul est ajoutée pour combiner toutes les informations de la séquence. Cette couche est un simple Multi-Layer-Perceptron avec une couche cachée et une non linéarité de type [RELU](https://pytorch.org/docs/stable/generated/torch.nn.ReLU.html).
# ![multi feedfoward](images/multi_ff.png)

# %%
class FeedForward(nn.Module):
    """ a simple MLP with RELU """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, n_embd),
            nn.ReLU(),
        )

    def forward(self, x):
        return self.net(x)

# %% [markdown]
# Questions :
# > * Ajouter le module `FeedForward` dans votre fichier `gpt_multi_head.py`.
# > * Ajouter cette couche `FeedForward` après la *multi-head attention*.
# > * Relancer l'entrainement et noter le nombre de paramètres et les loss obtenues.

# %%
# 0.011045 M parameters
# step 4999: train loss 2.1069, val loss 2.1455

# %% [markdown]
# 0.010949 M parameters
# step 4999: train loss 2.1290, val loss 2.1216

# %% [markdown]
# ## Empiler les blocs
#
# Le réseau construit jusqu'à présent n'est en fait qu'un bloc du réseau final. Il est maintenant possible d'empiler les blocs de *multi-head attention* pour créer un réseau profond.
#
# ![multi feedfoward](images/multi_bloc.png)
#
#
# Le code suivant crée un bloc :

# %%
class Block(nn.Module):
    """ A single bloc of multi-head attention """

    def __init__(self, n_embd, n_head):
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedForward(n_embd)

    def forward(self, x):
        x = self.sa(x)
        x = self.ffwd(x)
        return x

# %% [markdown]
# Questions :
# > * Ajouter le module `Block` dans `gpt_multi_head.py`.
# > * Modifier le code de `BigramLanguageModel` pour ajouter 3 `Block(n_embd, n_head=4)` avec un container [Sequential](https://pytorch.org/docs/stable/generated/torch.nn.Sequential.html) à la place de `MultiHeadAttention`et `FeedForward`.
# > * Relancer l'entrainement et noter le nombre de paramètres et les loss obtenues.
#
# 0.019205 M parameters
# step 4999: train loss 2.2080, val loss 2.2213

# %%
# 0.019493 M parameters
# step 4999: train loss 2.2031, val loss 2.2435

# %% [markdown]
# ## Amélioration de l'entraînement
#
# Si on veut continuer à augmenter la taille du réseau, il est nécessaire d'utiliser des couches permettant d'améliorer l'entraînement et ses capacités de généralisation (réduire le sur-apprentissage). Ces couches sont :
# - *skip connections* ou *residual connections*
# - les couches de normalisation
# - le dropout.
#
#
# ![multi feedfoward](images/multi_skip_norm.png)
#
#
# Questions :
# > * Dans le module Block, ajouter une skip connection en ajoutant l'input dans chaque connexion :
# ```
#         x = x + self.sa(self.ln1(x))
#         x = x + self.ffwd(self.ln2(x))
# ```
# > * Dans le module Block, ajouter 2 couches de [LayerNorm](https://pytorch.org/docs/stable/generated/torch.nn.LayerNorm.html) de taille `n_embd` avant la couche de `Multi-Head attention` et avant la `FeedForward`.
# > * Après la série de 3 blocs, ajouter une couche de LayerNorm de taille `n_embd`.
# > * Définir une variable `dropout = 0.2` en début de fichier et ajouter une couche de [Dropout](https://pytorch.org/docs/stable/generated/torch.nn.Dropout.html) :
# >    * Après la couche RELU dans FeedForward
# >    * Après la couche de MultiHead dans `MultiHeadAttention`
# >    * Après la softmax dans la single head attention `Head`.
# > * Relancer l'entrainement et noter le nombre de paramètres et les loss obtenues.
#
# 0.019653 M parameters

# %%
# 0.019941 M parameters

# %% [markdown]
# ## Conclusion
#
# Les principaux éléments de GPT2 sont en place, il faut maintenant faire passer le modèle à l'échelle et l'entraîner sur une base de données beaucoup plus grande. Pour comparaison, les paramètres de [GPT2](https://huggingface.co/transformers/v2.11.0/model_doc/gpt2.html) sont :
#
# * `vocab_size = 50257` : GPT2 modélise des tokens (subwords) alors que nous modélisons des caractères. Pour nous, `vocab_size = 100`.
# * `n_positions = 1024` : la taille maximale du contexte. Pour nous, c'est `block_size = 8`.
# * `n_embd = 768`:  la dimension des embeddings. Pour nous c'est `n_embd = 32`.
# * `n_layer = 12`: le nombre de block. Pour nous c'est 3.
# * `n_head = 12`: le nombre de multi-head attention. Pour nous c'est 4.
#
# Au total, GPT2 est composé de 1,500 millions de paramètres et a été entrainé sur 8M de pages web, soit 40 Gb de texte.
#
#
# ```
# 10.816613 M parameters
# step 0: train loss 4.7847, val loss 4.7701
# step 4999: train loss 0.2683, val loss 2.1161
# time: 31m47.910s
#
# Le pêcheur où l'homme en peu de Carevante
# Sa conter des chosses qu'en ses yoitn!
#
# Ils sont là-hauts parler à leurs ténèbres
# A ceux qu'on rêve aux oiseaux des cheveux,
# Et celus qu'on tourna jamais sous le front;
# Ils se disent tu mêle aux univers.
# J'ai vu Jean vu France, potte; petits contempler,
# Et petié calme au milibre et versait,
# M'éblouissant, emportant, écoute, ingorancessible,
# On meurt s'efferayait.....--Pas cont âme parle en Apparia!
# ```
